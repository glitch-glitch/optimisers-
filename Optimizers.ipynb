# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape, y_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# (60000, 28, 28) (60000,)

# %%
x_train= x_train.reshape(x_train.shape[0],28,28,1)
x_test=  x_test.reshape(x_test.shape[0],28,28,1)
input_shape=(28,28,1)
y_train=keras.utils.to_categorical(y_train)#,num_classes=)
y_test=keras.utils.to_categorical(y_test)#, num_classes)
x_train= x_train.astype('float32')
x_test= x_test.astype('float32')
x_train /= 255
x_test /=255

# %%
batch_size=64

num_classes=10

epochs=10

def build_model(optimizer):

    model=Sequential()

    model.add(Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=input_shape))

    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Dropout(0.25))

    model.add(Flatten())

    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(num_classes, activation='softmax'))

    model.compile(loss=keras.losses.categorical_crossentropy, optimizer= optimizer, metrics=['accuracy'])

    return model

# %%
optimizers = ['Adadelta', 'Adagrad', 'Adam', 'RMSprop', 'SGD']

for i in optimizers:

    model = build_model(i)

    hist=model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 938/938 [==============================] - 20s 20ms/step - loss: 2.2512 - accuracy: 0.1787 - val_loss: 2.1620 - val_accuracy: 0.4409
# Epoch 2/10
# 938/938 [==============================] - 20s 22ms/step - loss: 2.1205 - accuracy: 0.3497 - val_loss: 2.0149 - val_accuracy: 0.6146
# Epoch 3/10
# 938/938 [==============================] - 21s 22ms/step - loss: 1.9808 - accuracy: 0.4822 - val_loss: 1.8535 - val_accuracy: 0.6989
# Epoch 4/10
# 938/938 [==============================] - 21s 22ms/step - loss: 1.8299 - accuracy: 0.5630 - val_loss: 1.6840 - val_accuracy: 0.7476
# Epoch 5/10
# 938/938 [==============================] - 21s 22ms/step - loss: 1.6754 - accuracy: 0.6136 - val_loss: 1.5154 - val_accuracy: 0.7737
# Epoch 6/10
# 938/938 [==============================] - 20s 22ms/step - loss: 1.5258 - accuracy: 0.6522 - val_loss: 1.3558 - val_accuracy: 0.7935
# Epoch 7/10
# 938/938 [==============================] - 20s 22ms/step - loss: 1.3859 - accuracy: 0.6807 - val_loss: 1.2118 - val_accuracy: 0.8050
# Epoch 8/10
# 938/938 [==============================] - 20s 22ms/step - loss: 1.2626 - accuracy: 0.7013 - val_loss: 1.0860 - val_accuracy: 0.8172
# Epoch 9/10
# 938/938 [==============================] - 20s 21ms/step - loss: 1.1571 - accuracy: 0.7187 - val_loss: 0.9792 - val_accuracy: 0.8269
# Epoch 10/10
# 938/938 [==============================] - 20s 21ms/step - loss: 1.0661 - accuracy: 0.7310 - val_loss: 0.8893 - val_accuracy: 0.8369
# Epoch 1/10
# 938/938 [==============================] - 20s 21ms/step - loss: 1.5303 - accuracy: 0.5745 - val_loss: 0.7380 - val_accuracy: 0.8508
# Epoch 2/10
# 938/938 [==============================] - 19s 21ms/step - loss: 0.7303 - accuracy: 0.7913 - val_loss: 0.4647 - val_accuracy: 0.8850
# Epoch 3/10
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0945 - accuracy: 0.9717 - val_loss: 0.0560 - val_accuracy: 0.9816
# Epoch 3/10
# 938/938 [==============================] - 24s 26ms/step - loss: 0.0732 - accuracy: 0.9785 - val_loss: 0.0475 - val_accuracy: 0.9846
# Epoch 4/10
# 938/938 [==============================] - 25s 26ms/step - loss: 0.0662 - accuracy: 0.9808 - val_loss: 0.0584 - val_accuracy: 0.9830
# Epoch 5/10
# 938/938 [==============================] - 26s 28ms/step - loss: 0.0612 - accuracy: 0.9825 - val_loss: 0.0513 - val_accuracy: 0.9839
# Epoch 6/10
# 938/938 [==============================] - 23s 25ms/step - loss: 0.0573 - accuracy: 0.9834 - val_loss: 0.0476 - val_accuracy: 0.9856
# Epoch 7/10
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0579 - accuracy: 0.9838 - val_loss: 0.0495 - val_accuracy: 0.9864
# Epoch 8/10
# 938/938 [==============================] - 27s 28ms/step - loss: 0.0596 - accuracy: 0.9836 - val_loss: 0.0474 - val_accuracy: 0.9865
# Epoch 9/10
# 938/938 [==============================] - 25s 27ms/step - loss: 0.0570 - accuracy: 0.9834 - val_loss: 0.0575 - val_accuracy: 0.9836
# Epoch 10/10
# 938/938 [==============================] - 24s 26ms/step - loss: 0.0573 - accuracy: 0.9837 - val_loss: 0.0558 - val_accuracy: 0.9863
# Epoch 1/10
# 938/938 [==============================] - 20s 21ms/step - loss: 0.8318 - accuracy: 0.7486 - val_loss: 0.2994 - val_accuracy: 0.9171
# Epoch 2/10
# 938/938 [==============================] - 19s 20ms/step - loss: 0.3805 - accuracy: 0.8845 - val_loss: 0.2253 - val_accuracy: 0.9348
# Epoch 3/10
# 938/938 [==============================] - 19s 20ms/step - loss: 0.3124 - accuracy: 0.9057 - val_loss: 0.1877 - val_accuracy: 0.9438
# Epoch 4/10
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2687 - accuracy: 0.9197 - val_loss: 0.1645 - val_accuracy: 0.9511
# Epoch 5/10
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2435 - accuracy: 0.9275 - val_loss: 0.1514 - val_accuracy: 0.9550
# Epoch 6/10
# 938/938 [==============================] - 19s 20ms/step - loss: 0.2272 - accuracy: 0.9310 - val_loss: 0.1364 - val_accuracy: 0.9587
# Epoch 7/10
# 938/938 [==============================] - 19s 20ms/step - loss: 0.2080 - accuracy: 0.9379 - val_loss: 0.1276 - val_accuracy: 0.9632
# Epoch 8/10
# 938/938 [==============================] - 19s 20ms/step - loss: 0.1973 - accuracy: 0.9406 - val_loss: 0.1190 - val_accuracy: 0.9652
# Epoch 9/10
# 938/938 [==============================] - 19s 20ms/step - loss: 0.1867 - accuracy: 0.9436 - val_loss: 0.1133 - val_accuracy: 0.9642
# Epoch 10/10
# 938/938 [==============================] - 19s 20ms/step - loss: 0.1802 - accuracy: 0.9451 - val_loss: 0.1056 - val_accuracy: 0.9682

# %%
print(model)
